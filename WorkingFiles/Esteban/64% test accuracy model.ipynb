# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using device: ",device)
# Out:
# Using device:  cuda

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import os
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, ReLU, Add, Input, ZeroPadding2D, BatchNormalization, Activation, MaxPooling2D,AveragePooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from tensorflow.keras.applications import ResNet50V2
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
import torch
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn

import cv2
import imutils
import matplotlib.pyplot as plt
import time
from os import listdir
import warnings
warnings.filterwarnings("ignore")
from tensorflow.keras.utils import to_categorical


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" director
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('data\cifar-10-batches-py'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# data\cifar-10-batches-py\batches.meta
# data\cifar-10-batches-py\data_batch_1
# data\cifar-10-batches-py\data_batch_2
# data\cifar-10-batches-py\data_batch_3
# data\cifar-10-batches-py\data_batch_4
# data\cifar-10-batches-py\data_batch_5
# data\cifar-10-batches-py\readme.html
# data\cifar-10-batches-py\test_batch

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pickle

def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = 'data\cifar-10-batches-py'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load one batch for demonstration (e.g., data_batch_1)
batch_1_dict = load_cifar_batch(os.path.join(cifar10_dir, 'data_batch_1'))
train_images = batch_1_dict[b'data']
train_labels = batch_1_dict[b'labels']

# Reshape the images
train_images = train_images.reshape((10000, 3, 32, 32)).transpose(0, 2, 3, 1)

# Display the first 10 images and labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(train_images[i])
    plt.title(label_names[train_labels[i]].decode('utf-8'))  # Decoding from bytes to string
    plt.axis('off')
plt.show()

# %%
train_images.shape
# Out:
# (10000, 32, 32, 3)

# %% [markdown]
# There are 10000 samples in 1st batch

# %% [markdown]
# ## Combine all 5 training batches

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt

cifar10_dir = 'data/cifar-10-batches-py'

# Load metadata
with open(os.path.join(cifar10_dir, 'batches.meta'), 'rb') as fo:
    meta_data_dict = pickle.load(fo, encoding='bytes')
label_names = [label.decode('utf-8') for label in meta_data_dict[b'label_names']]

# Initialize lists
all_images = []
all_labels = []

# Corrected loading loop
batch_files = ['data_batch_1', 'data_batch_2', 'data_batch_3', 'data_batch_4', 'data_batch_5']

for file in batch_files:
    with open(os.path.join(cifar10_dir, file), 'rb') as fo:
        batch_dict = pickle.load(fo, encoding='bytes')
        images = batch_dict[b'data']
        labels = batch_dict[b'labels']
        all_images.append(images)
        all_labels.extend(labels)

# Stack and reshape images correctly
all_images = np.vstack(all_images)
all_images = all_images.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

all_labels = np.array(all_labels)

# Visualize the first 10 images
plt.figure(figsize=(20, 5))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.imshow(all_images[i])
    plt.title(label_names[all_labels[i]])
    plt.axis('off')
plt.show()

# %%
import cv2
from tqdm import tqdm  # to monitor progress easily

def sharpen_image(image):
    kernel = np.array([[0, -1, 0],
                       [-1, 5, -1],
                       [0, -1, 0]])
    return cv2.filter2D(src=image, ddepth=-1, kernel=kernel)

# Sharpening all images
sharpened_images = np.empty_like(all_images)

for i in tqdm(range(len(all_images)), desc="Sharpening images"):
    sharpened_images[i] = sharpen_image(all_images[i])

# Displaying some examples
plt.figure(figsize=(20, 5))
for i in range(10):
    plt.subplot(2, 10, i + 1)
    plt.imshow(all_images[i])
    plt.title(label_names[all_labels[i]])
    plt.axis('off')

    plt.subplot(2, 10, i + 11)
    plt.imshow(sharpened_images[i])
    plt.title(f"{label_names[all_labels[i]]}\n(sharpened)")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Sharpening images: 100%|██████████| 50000/50000 [00:00<00:00, 65089.14it/s]

# %%
sharpened_images.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# There are 50000 images/ samples in the dataset and each of them are 32 x 32 pixel RGB image

# %%
all_labels.shape
# Out:
# (50000,)

# %%
unique_labels, counts = np.unique(all_labels, return_counts=True)
label_counts = dict(zip(unique_labels, counts))

print(label_counts)
# Out:
# {np.int64(0): np.int64(5000), np.int64(1): np.int64(5000), np.int64(2): np.int64(5000), np.int64(3): np.int64(5000), np.int64(4): np.int64(5000), np.int64(5): np.int64(5000), np.int64(6): np.int64(5000), np.int64(7): np.int64(5000), np.int64(8): np.int64(5000), np.int64(9): np.int64(5000)}

# %% [markdown]
# Every class has equal number of samples, therefore, it is a balanced dataset

# %% [markdown]
# # Pre-Processing the Dataset
# ### 1. Normalize Pixel Values (Feature Scaling)

# %% [markdown]
# ### Standardize the dataset (mean = 0, std = 1):

# %%
# Compute mean/std ONCE (on the entire dataset BEFORE splitting)
train_mean = np.mean(sharpened_images, axis=(0,1,2))
train_std = np.std(sharpened_images, axis=(0,1,2))
all_images = (sharpened_images - train_mean) / train_std

# %%
# Standardize training dataset using TRAINING data mean/std:
train_mean = np.mean(sharpened_images, axis=(0,1,2))
train_std = np.std(sharpened_images, axis=(0,1,2))

# Apply the normalization
all_images = (sharpened_images.astype('float32') / 255.0 - train_mean) / train_std

# %%
all_labels = to_categorical(all_labels, num_classes=10)

# %% [markdown]
# # Data Augmentation

# %%
'''
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,      
    width_shift_range=0.1,  
    height_shift_range=0.1, 
    horizontal_flip=True,   
    brightness_range=[0.8, 1.2],  
    zoom_range=0.2        
)

datagen.fit(all_images)  # Fit the generator to dataset
'''
# Out:
# '\nfrom tensorflow.keras.preprocessing.image import ImageDataGenerator\n\ndatagen = ImageDataGenerator(\n    rotation_range=15,      \n    width_shift_range=0.1,  \n    height_shift_range=0.1, \n    horizontal_flip=True,   \n    brightness_range=[0.8, 1.2],  \n    zoom_range=0.2        \n)\n\ndatagen.fit(all_images)  # Fit the generator to dataset\n'

# %%
'''
augmented_images, _ = next(datagen.flow(all_images, all_labels, batch_size=10))

# Display the augmented images
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(augmented_images[i])
    plt.axis('off')
plt.show()
'''
# Out:
# "\naugmented_images, _ = next(datagen.flow(all_images, all_labels, batch_size=10))\n\n# Display the augmented images\nplt.figure(figsize=(10, 5))\nfor i in range(10):\n    plt.subplot(2, 5, i+1)\n    plt.imshow(augmented_images[i])\n    plt.axis('off')\nplt.show()\n"

# %% [markdown]
# # Splitting the Data into train and validation set
#
# Let's use the following way to split:
#
# 70% of the data for training. 30% of the data for validation

# %%
X_train, X_val, y_train, y_val = train_test_split(all_images, all_labels, test_size=0.3, random_state=42)

# %%
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of validation examples = " + str(X_val.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(y_train.shape))
print ("X_val (dev) shape: " + str(X_val.shape))
print ("Y_val (dev) shape: " + str(y_val.shape))
# Out:
# number of training examples = 35000
# number of validation examples = 15000
# X_train shape: (35000, 32, 32, 3)
# Y_train shape: (35000, 10)
# X_val (dev) shape: (15000, 32, 32, 3)
# Y_val (dev) shape: (15000, 10)

# %% [markdown]
# # Build a ResNet Model
# Model Architecture

# %%
# Define Basic Residual Block
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, shortcut_kernel=1, stride=1, use_se=True):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, shortcut_kernel, stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )
        
        # Squeeze and Excitation (SE) block
        self.use_se = use_se
        if self.use_se:
            self.se = nn.Sequential(
                nn.AdaptiveAvgPool2d(1),
                nn.Conv2d(out_channels, out_channels // 16, 1),
                nn.ReLU(),
                nn.Conv2d(out_channels // 16, out_channels, 1),
                nn.Sigmoid()
            )

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        identity = self.shortcut(x)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        if self.use_se:
            se_weight = self.se(out)
            out = out * se_weight

        out += identity
        return self.relu(out)


# Define ResNet Model
class CustomResNet(nn.Module):
    def __init__(self, num_classes=10):
        super(CustomResNet, self).__init__()
        self.in_channels = 64

        # Initial convolution
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Residual layers configuration
        self.layers = self._make_layer([64, 128, 256], [[4, 4], [3, 4], [3]], kernel_sizes=[3, 3, 3])
        
        # Average pooling
        self.avg_pool = nn.AdaptiveAvgPool2d(8)

        # Fully connected layer
        self.fc = nn.Linear(256 * 8 * 8, num_classes)

    def _make_layer(self, channels, num_blocks, kernel_sizes):
        layers = []
        for i, (out_channels, blocks) in enumerate(zip(channels, num_blocks)):
            for _ in range(blocks[0]):  # Residual block counts
                layers.append(ResidualBlock(self.in_channels, out_channels, kernel_size=kernel_sizes[i]))
                self.in_channels = out_channels  # Ensure consistent input channel size
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.layers(out)
        out = self.avg_pool(out)
        out = torch.flatten(out, 1)
        out = self.fc(out)
        return out


# Instantiate Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CustomResNet(num_classes=10).to(device)

# Optimizer and Scheduler
optimizer = optim.SGD(model.parameters(), lr=0.1, weight_decay=0.0005)
scheduler = CosineAnnealingLR(optimizer, T_max=130)  # CosineAnnealingLR

# Loss function
criterion = nn.CrossEntropyLoss()

# Print model summary
print(model)
print('Using device: ',device)
# Out:
# CustomResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layers): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (2): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (3): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (4): ResidualBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (5): ResidualBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (6): ResidualBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (7): ResidualBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (8): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (9): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (se): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): ReLU()
#         (3): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#         (4): Sigmoid()
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=8)
#   (fc): Linear(in_features=16384, out_features=10, bias=True)
# )
# Using device:  cuda

# %%
#model = Model(inputs=base_model.input, outputs=output)

# %%
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"🔹 Total Parameters: {total_params:,}")
print(f"🔹 Trainable Parameters: {trainable_params:,}")
# Out:
# 🔹 Total Parameters: 4,597,282
# 🔹 Trainable Parameters: 4,597,282

# %%
# Convert NumPy arrays to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32).permute(0, 3, 1, 2)
y_train_tensor = torch.tensor(np.argmax(y_train, axis=1), dtype=torch.long)  # Convert one-hot labels to integers
X_val_tensor = torch.tensor(X_val, dtype=torch.float32).permute(0, 3, 1, 2)
y_val_tensor = torch.tensor(np.argmax(y_val, axis=1), dtype=torch.long)

# Create datasets and dataloaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

batch_no = 64
train_loader = DataLoader(train_dataset, batch_size=batch_no, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_no, shuffle=False)

# %% [markdown]
# # Train the model

# %%
# Set up the training loop
print("Using device: ",device)

epochs = 30
for epoch in range(epochs):
    model.train()  # Set model to training mode
    running_loss = 0.0
    running_acc = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()  # Zero the gradients



        try:
            outputs = model(inputs)  # Forward pass
            loss = criterion(outputs, labels)  # Compute loss
            loss.backward()  # Backpropagation
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0) #prevent exploding gradients
            optimizer.step()  # Update model weights
        
        except Exception as e:
            print(f'Error during training: {e}')
            print(f"Input shape: {inputs.shape}")
            print(f"Label shape: {labels.shape}")
            print(f"Memory allocated: {torch.cuda.memory_allocated() / 1e9} GB")
            break  # Exit the loop if there's an error


        # Calculate accuracy
        _, predicted = torch.max(outputs, 1)
        correct = (predicted == labels).sum().item()
        acc = correct / labels.size(0)

        running_loss += loss.item()
        running_acc += acc

    epoch_loss = running_loss / len(train_loader)
    epoch_acc = running_acc / len(train_loader)

    # Validation step
    model.eval()  # Set model to evaluation mode
    val_loss = 0.0
    val_acc = 0.0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)  # Forward pass
            loss = criterion(outputs, labels)  # Compute loss

            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            correct = (predicted == labels).sum().item()
            acc = correct / labels.size(0)

            val_loss += loss.item()
            val_acc += acc

    val_loss /= len(val_loader)
    val_acc /= len(val_loader)

    # Print the metrics for this epoch
    print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}, "
          f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")

    # Adjust the learning rate using the scheduler
    scheduler.step()
# Out:
# Using device:  cuda
# Epoch [1/30], Train Loss: 2.1404, Train Accuracy: 0.2723, Validation Loss: 3.1924, Validation Accuracy: 0.0979
# Epoch [2/30], Train Loss: 1.4310, Train Accuracy: 0.4833, Validation Loss: 5.8670, Validation Accuracy: 0.1068
# Epoch [3/30], Train Loss: 1.1575, Train Accuracy: 0.5919, Validation Loss: 10.6205, Validation Accuracy: 0.0985
# Epoch [4/30], Train Loss: 0.9932, Train Accuracy: 0.6510, Validation Loss: 4.8661, Validation Accuracy: 0.0979
# Epoch [5/30], Train Loss: 0.8832, Train Accuracy: 0.6894, Validation Loss: 4.0800, Validation Accuracy: 0.0966
# Epoch [6/30], Train Loss: 0.7887, Train Accuracy: 0.7228, Validation Loss: 10.6135, Validation Accuracy: 0.0985
# Epoch [7/30], Train Loss: 0.7106, Train Accuracy: 0.7507, Validation Loss: 8.4349, Validation Accuracy: 0.1028
# Epoch [8/30], Train Loss: 0.6592, Train Accuracy: 0.7706, Validation Loss: 4.6095, Validation Accuracy: 0.1029
# Epoch [9/30], Train Loss: 0.5918, Train Accuracy: 0.7930, Validation Loss: 8.9894, Validation Accuracy: 0.0991
# Epoch [10/30], Train Loss: 0.5377, Train Accuracy: 0.8113, Validation Loss: 6.9726, Validation Accuracy: 0.0977
# Epoch [11/30], Train Loss: 0.4903, Train Accuracy: 0.8293, Validation Loss: 15.1903, Validation Accuracy: 0.1001
# Epoch [12/30], Train Loss: 0.4647, Train Accuracy: 0.8383, Validation Loss: 4.2659, Validation Accuracy: 0.1070
# Epoch [13/30], Train Loss: 0.4185, Train Accuracy: 0.8537, Validation Loss: 5.5845, Validation Accuracy: 0.1001
# Epoch [14/30], Train Loss: 0.3794, Train Accuracy: 0.8682, Validation Loss: 7.0012, Validation Accuracy: 0.0979
# Epoch [15/30], Train Loss: 0.3368, Train Accuracy: 0.8853, Validation Loss: 6.7301, Validation Accuracy: 0.1056
# Epoch [16/30], Train Loss: 0.3032, Train Accuracy: 0.8965, Validation Loss: 9.1822, Validation Accuracy: 0.1017
# Epoch [17/30], Train Loss: 0.2661, Train Accuracy: 0.9108, Validation Loss: 2.8070, Validation Accuracy: 0.2187
# Epoch [18/30], Train Loss: 0.2371, Train Accuracy: 0.9225, Validation Loss: 14.6678, Validation Accuracy: 0.1029
# Epoch [19/30], Train Loss: 0.2052, Train Accuracy: 0.9347, Validation Loss: 4.3645, Validation Accuracy: 0.1664
# Epoch [20/30], Train Loss: 0.1801, Train Accuracy: 0.9425, Validation Loss: 4.8121, Validation Accuracy: 0.2190
# Epoch [21/30], Train Loss: 0.1560, Train Accuracy: 0.9522, Validation Loss: 5.6532, Validation Accuracy: 0.1120
# Epoch [22/30], Train Loss: 0.1386, Train Accuracy: 0.9585, Validation Loss: 14.6241, Validation Accuracy: 0.1324
# Epoch [23/30], Train Loss: 0.1228, Train Accuracy: 0.9647, Validation Loss: 5.3084, Validation Accuracy: 0.1017
# Epoch [24/30], Train Loss: 0.1081, Train Accuracy: 0.9700, Validation Loss: 4.5888, Validation Accuracy: 0.1135
# Epoch [25/30], Train Loss: 0.0946, Train Accuracy: 0.9751, Validation Loss: 4.3504, Validation Accuracy: 0.2788
# Epoch [26/30], Train Loss: 0.0861, Train Accuracy: 0.9773, Validation Loss: 6.9019, Validation Accuracy: 0.1029
# Epoch [27/30], Train Loss: 0.0774, Train Accuracy: 0.9811, Validation Loss: 5.3830, Validation Accuracy: 0.1548
# Epoch [28/30], Train Loss: 0.0703, Train Accuracy: 0.9817, Validation Loss: 2.8129, Validation Accuracy: 0.2611
# Epoch [29/30], Train Loss: 0.0651, Train Accuracy: 0.9843, Validation Loss: 3.5945, Validation Accuracy: 0.2668
# Epoch [30/30], Train Loss: 0.0572, Train Accuracy: 0.9874, Validation Loss: 1.0929, Validation Accuracy: 0.6795

# %% [markdown]
# # Model Checkpoints (Optional):

# %%
# Save checkpoint after each epoch
torch.save(model.state_dict(), f"model_epoch_{epoch+1}.pth")

# %% [markdown]
# # Test Data

# %%
# Load test data
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Load the batch
cifar10_batch = load_cifar_batch('cifar_test_nolabel.pkl')

# Extract images
test_images = cifar10_batch[b'data']

# Check the shape of test_images and reshape if necessary
print(f"Original test images shape: {test_images.shape}")

# If test_images is in flat format (N, 3072), reshape it
if len(test_images.shape) == 2 and test_images.shape[1] == 3072:
    test_images = test_images.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
    print(f"Reshaped test images to: {test_images.shape}")

# Use the same normalization as training data
test_images = (test_images.astype('float32') / 255.0 - train_mean) / train_std

# Convert test dataset to Tensor - correctly permute the channels
test_tensor = torch.tensor(test_images, dtype=torch.float32).permute(0, 3, 1, 2)
print(f"Final test tensor shape: {test_tensor.shape}")

test_dataset = TensorDataset(test_tensor, torch.zeros(len(test_tensor), dtype=torch.long))
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Generate submission file
model.eval()
predictions = []
with torch.no_grad():
    for images, _ in test_loader:  # Note: we're ignoring the dummy labels
        images = images.to(device)
        # No need to permute here since we've already permuted when creating the tensor
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())

print(f"Total predictions: {len(predictions)}")
# Out:
# Original test images shape: (10000, 32, 32, 3)
# Final test tensor shape: torch.Size([10000, 3, 32, 32])
# Total predictions: 10000

# %%
# Display the first 10 images
plt.figure(figsize=(20, 4))
for i in range(20):
    plt.subplot(2, 10, i+1)
    plt.imshow(test_images[i])
    plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5534851993546566..-1.379355062858545].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5540192337966654..-1.3794025062754043].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5492614724461502..-1.3776470998516086].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5537279422849388..-1.3805411482800285].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5540192337966654..-1.3794499496922636].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5536308450989904..-1.3794025062754043].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5540192337966654..-1.3779317603527648].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5530968106569816..-1.3823439981206833].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5537764908663834..-1.3776470998516086].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.551300513051296..-1.377694543268468].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5535822965175459..-1.3784061945213582].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5530968106569816..-1.3780740906033426].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5539221366222467..-1.3784061945213582].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5539221366222467..-1.3776470998516086].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5526598734239807..-1.3776470998516086].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.551834547447186..-1.3808258087811844].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5540192337966654..-1.3786434116056547].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5539221366222467..-1.3785010813550769].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5532910050288784..-1.3776470998516086].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.551834547447186..-1.378121534020202].

# %% [markdown]
# # Pre-Process the test data

# %%
# images.shape

# %%
# images = images.astype('float32') / 255.0  # Normalize to range [0, 1]

# %%
# Correctly standardize test data using TRAIN mean/std
# images = (images.astype('float32') / 255.0 - train_mean) / train_std

# %%
# Convert test dataset to Tensor
# test_tensor = torch.tensor(images, dtype=torch.float32)
# test_loader = DataLoader(test_tensor, batch_size=128, shuffle=False)

# %%
# Generate submission file
# model.eval()
# predictions = []
# with torch.no_grad():
#     for images in test_loader:
#         images = images.to(device)
#         images = images.permute(0, 3, 1, 2)
#         outputs = model(images) 
#         _, predicted = torch.max(outputs, 1)
#         predictions.extend(predicted.cpu().numpy())

# print(predictions)

# %%
# submission = pd.DataFrame({
#     'ID': np.arange(len(predictions)),
#     'Labels': predictions
# })

# %%
# submission.to_csv('submission1.csv', index=False)
